# %% [markdown]
# ---
# title: Tiny Notebook Example
# ---
#
# # Tiny Notebook Example
#
# This notebook is rendered by the `webifier.notebook` extension.

# %%
{"files": ["index.yml", "notebook.ipynb"], "published": True}
# Out:
# {'files': ['index.yml', 'notebook.ipynb'], 'published': True}
